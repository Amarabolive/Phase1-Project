# %%
# Importing data
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Refugee_Asylum_data.csv")
df.head()
# Out:
#    Year Country of origin Country of asylum  Refugees under UNHCR's mandate  \
# 0  2019       Afghanistan       Afghanistan                               0
# 1  2019       Afghanistan             Egypt                              28
# 2  2019       Afghanistan         Argentina                              12
# 3  2019       Afghanistan           Armenia                               5
# 4  2019       Afghanistan         Australia                           11585
#
#    Asylum-seekers  Returned refugees  IDPs of concern to UNHCR  \
# 0               0                  0                   2553390
# 1              36                  0                         0
# 2               0                  0                         0
# 3               0                  0                         0
# 4            1710                  0                         0
#
#    Returned IDPss  Stateless persons  Others of concern  \
# 0               0                  0             447093
# ...

# %%
df
# Out:
#        Year Country of origin         Country of asylum  \
# 0      2019       Afghanistan               Afghanistan
# 1      2019       Afghanistan                     Egypt
# 2      2019       Afghanistan                 Argentina
# 3      2019       Afghanistan                   Armenia
# 4      2019       Afghanistan                 Australia
# ...     ...               ...                       ...
# 34595  2024          Zimbabwe               Switzerland
# 34596  2024          Zimbabwe                  Thailand
# 34597  2024          Zimbabwe  United States of America
# 34598  2024          Zimbabwe                    Zambia
# 34599  2024          Zimbabwe                  Zimbabwe
#
#        Refugees under UNHCR's mandate  Asylum-seekers  Returned refugees  \
# 0                                   0               0                  0
# 1                                  28              36                  0
# ...

# %%
# checking if we have duplicates and droping them
df.drop_duplicates()
# Out:
#        Year Country of origin         Country of asylum  \
# 0      2019       Afghanistan               Afghanistan
# 1      2019       Afghanistan                     Egypt
# 2      2019       Afghanistan                 Argentina
# 3      2019       Afghanistan                   Armenia
# 4      2019       Afghanistan                 Australia
# ...     ...               ...                       ...
# 34595  2024          Zimbabwe               Switzerland
# 34596  2024          Zimbabwe                  Thailand
# 34597  2024          Zimbabwe  United States of America
# 34598  2024          Zimbabwe                    Zambia
# 34599  2024          Zimbabwe                  Zimbabwe
#
#        Refugees under UNHCR's mandate  Asylum-seekers  Returned refugees  \
# 0                                   0               0                  0
# 1                                  28              36                  0
# ...

# %%
# dropping columns we do need
df = df.drop(columns = "Returned refugees")
df
# Out:
#        Year Country of origin         Country of asylum  \
# 0      2019       Afghanistan               Afghanistan
# 1      2019       Afghanistan                     Egypt
# 2      2019       Afghanistan                 Argentina
# 3      2019       Afghanistan                   Armenia
# 4      2019       Afghanistan                 Australia
# ...     ...               ...                       ...
# 34595  2024          Zimbabwe               Switzerland
# 34596  2024          Zimbabwe                  Thailand
# 34597  2024          Zimbabwe  United States of America
# 34598  2024          Zimbabwe                    Zambia
# 34599  2024          Zimbabwe                  Zimbabwe
#
#        Refugees under UNHCR's mandate  Asylum-seekers  \
# 0                                   0               0
# 1                                  28              36
# 2                                  12               0
# 3                                   5               0
# ...

# %%
df = df.drop(columns = "Stateless persons")
df
# Out:
#        Year Country of origin         Country of asylum  \
# 0      2019       Afghanistan               Afghanistan
# 1      2019       Afghanistan                     Egypt
# 2      2019       Afghanistan                 Argentina
# 3      2019       Afghanistan                   Armenia
# 4      2019       Afghanistan                 Australia
# ...     ...               ...                       ...
# 34595  2024          Zimbabwe               Switzerland
# 34596  2024          Zimbabwe                  Thailand
# 34597  2024          Zimbabwe  United States of America
# 34598  2024          Zimbabwe                    Zambia
# 34599  2024          Zimbabwe                  Zimbabwe
#
#        Refugees under UNHCR's mandate  Asylum-seekers  \
# 0                                   0               0
# 1                                  28              36
# 2                                  12               0
# 3                                   5               0
# ...

# %%
df = df.drop(columns = "Returned IDPss")
df
# Out:
#        Year Country of origin         Country of asylum  \
# 0      2019       Afghanistan               Afghanistan
# 1      2019       Afghanistan                     Egypt
# 2      2019       Afghanistan                 Argentina
# 3      2019       Afghanistan                   Armenia
# 4      2019       Afghanistan                 Australia
# ...     ...               ...                       ...
# 34595  2024          Zimbabwe               Switzerland
# 34596  2024          Zimbabwe                  Thailand
# 34597  2024          Zimbabwe  United States of America
# 34598  2024          Zimbabwe                    Zambia
# 34599  2024          Zimbabwe                  Zimbabwe
#
#        Refugees under UNHCR's mandate  Asylum-seekers  \
# 0                                   0               0
# 1                                  28              36
# 2                                  12               0
# 3                                   5               0
# ...

# %%
df = df.drop(columns = "Other people in need of international protection")
df
# Out:
#        Year Country of origin         Country of asylum  \
# 0      2019       Afghanistan               Afghanistan
# 1      2019       Afghanistan                     Egypt
# 2      2019       Afghanistan                 Argentina
# 3      2019       Afghanistan                   Armenia
# 4      2019       Afghanistan                 Australia
# ...     ...               ...                       ...
# 34595  2024          Zimbabwe               Switzerland
# 34596  2024          Zimbabwe                  Thailand
# 34597  2024          Zimbabwe  United States of America
# 34598  2024          Zimbabwe                    Zambia
# 34599  2024          Zimbabwe                  Zimbabwe
#
#        Refugees under UNHCR's mandate  Asylum-seekers  \
# 0                                   0               0
# 1                                  28              36
# 2                                  12               0
# 3                                   5               0
# ...

# %%
df = df.drop(columns = "Host Community")
df
# Out:
#        Year Country of origin         Country of asylum  \
# 0      2019       Afghanistan               Afghanistan
# 1      2019       Afghanistan                     Egypt
# 2      2019       Afghanistan                 Argentina
# 3      2019       Afghanistan                   Armenia
# 4      2019       Afghanistan                 Australia
# ...     ...               ...                       ...
# 34595  2024          Zimbabwe               Switzerland
# 34596  2024          Zimbabwe                  Thailand
# 34597  2024          Zimbabwe  United States of America
# 34598  2024          Zimbabwe                    Zambia
# 34599  2024          Zimbabwe                  Zimbabwe
#
#        Refugees under UNHCR's mandate  Asylum-seekers  \
# 0                                   0               0
# 1                                  28              36
# 2                                  12               0
# 3                                   5               0
# ...

# %%
df
# Out:
#        Year Country of origin         Country of asylum  \
# 0      2019       Afghanistan               Afghanistan
# 1      2019       Afghanistan                     Egypt
# 2      2019       Afghanistan                 Argentina
# 3      2019       Afghanistan                   Armenia
# 4      2019       Afghanistan                 Australia
# ...     ...               ...                       ...
# 34595  2024          Zimbabwe               Switzerland
# 34596  2024          Zimbabwe                  Thailand
# 34597  2024          Zimbabwe  United States of America
# 34598  2024          Zimbabwe                    Zambia
# 34599  2024          Zimbabwe                  Zimbabwe
#
#        Refugees under UNHCR's mandate  Asylum-seekers  \
# 0                                   0               0
# 1                                  28              36
# 2                                  12               0
# 3                                   5               0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        Year Country of origin         Country of asylum  \
# 0      2019       Afghanistan               Afghanistan
# 1      2019       Afghanistan                     Egypt
# 2      2019       Afghanistan                 Argentina
# 3      2019       Afghanistan                   Armenia
# 4      2019       Afghanistan                 Australia
# ...     ...               ...                       ...
# 34595  2024          Zimbabwe               Switzerland
# 34596  2024          Zimbabwe                  Thailand
# 34597  2024          Zimbabwe  United States of America
# 34598  2024          Zimbabwe                    Zambia
# 34599  2024          Zimbabwe                  Zimbabwe
#
#        Refugees under UNHCR's mandate  Asylum-seekers  \
# 0                                   0               0
# 1                                  28              36
# 2                                  12               0
# ...

# %%
df
# Out:
#        Year Country of origin         Country of asylum  \
# 0      2019       Afghanistan               Afghanistan
# 1      2019       Afghanistan                     Egypt
# 2      2019       Afghanistan                 Argentina
# 3      2019       Afghanistan                   Armenia
# 4      2019       Afghanistan                 Australia
# ...     ...               ...                       ...
# 34595  2024          Zimbabwe               Switzerland
# 34596  2024          Zimbabwe                  Thailand
# 34597  2024          Zimbabwe  United States of America
# 34598  2024          Zimbabwe                    Zambia
# 34599  2024          Zimbabwe                  Zimbabwe
#
#        Refugees under UNHCR's mandate  Asylum-seekers  \
# 0                                   0               0
# 1                                  28              36
# 2                                  12               0
# 3                                   5               0
# ...

# %%
df.describe()
# Out:
#                Year  Refugees under UNHCR's mandate  Asylum-seekers  \
# count  34600.000000                    3.460000e+04    34600.000000
# mean    2021.576416                    4.492106e+03      960.869855
# std        1.705930                    7.118794e+04    10986.811413
# min     2019.000000                    0.000000e+00        0.000000
# 25%     2020.000000                    5.000000e+00        0.000000
# 50%     2022.000000                    1.200000e+01       10.000000
# 75%     2023.000000                    8.225000e+01       80.000000
# max     2024.000000                    3.752317e+06   620074.000000
#
#        IDPs of concern to UNHCR  Others of concern
# count              3.460000e+04       3.460000e+04
# mean               9.566760e+03       7.482390e+02
# std                2.081691e+05       3.172753e+04
# min                0.000000e+00       0.000000e+00
# 25%                0.000000e+00       0.000000e+00
# ...

# %%
# checking for total missing values
df.isnull().sum()
# Out:
# Year                              0
# Country of origin                 0
# Country of asylum                 0
# Refugees under UNHCR's mandate    0
# Asylum-seekers                    0
# IDPs of concern to UNHCR          0
# Others of concern                 0
# dtype: int64

# %%
df
# Out:
#        Year Country of origin         Country of asylum  \
# 0      2019       Afghanistan               Afghanistan
# 1      2019       Afghanistan                     Egypt
# 2      2019       Afghanistan                 Argentina
# 3      2019       Afghanistan                   Armenia
# 4      2019       Afghanistan                 Australia
# ...     ...               ...                       ...
# 34595  2024          Zimbabwe               Switzerland
# 34596  2024          Zimbabwe                  Thailand
# 34597  2024          Zimbabwe  United States of America
# 34598  2024          Zimbabwe                    Zambia
# 34599  2024          Zimbabwe                  Zimbabwe
#
#        Refugees under UNHCR's mandate  Asylum-seekers  \
# 0                                   0               0
# 1                                  28              36
# 2                                  12               0
# 3                                   5               0
# ...

# %%
df[df.Year >1]
# Out:
#        Year Country of origin         Country of asylum  \
# 0      2019       Afghanistan               Afghanistan
# 1      2019       Afghanistan                     Egypt
# 2      2019       Afghanistan                 Argentina
# 3      2019       Afghanistan                   Armenia
# 4      2019       Afghanistan                 Australia
# ...     ...               ...                       ...
# 34595  2024          Zimbabwe               Switzerland
# 34596  2024          Zimbabwe                  Thailand
# 34597  2024          Zimbabwe  United States of America
# 34598  2024          Zimbabwe                    Zambia
# 34599  2024          Zimbabwe                  Zimbabwe
#
#        Refugees under UNHCR's mandate  Asylum-seekers  \
# 0                                   0               0
# 1                                  28              36
# 2                                  12               0
# 3                                   5               0
# ...

# %%
df.to_csv('Year-filtered.csv')

# %%
df
# Out:
#        Year Country of origin         Country of asylum  \
# 0      2019       Afghanistan               Afghanistan
# 1      2019       Afghanistan                     Egypt
# 2      2019       Afghanistan                 Argentina
# 3      2019       Afghanistan                   Armenia
# 4      2019       Afghanistan                 Australia
# ...     ...               ...                       ...
# 34595  2024          Zimbabwe               Switzerland
# 34596  2024          Zimbabwe                  Thailand
# 34597  2024          Zimbabwe  United States of America
# 34598  2024          Zimbabwe                    Zambia
# 34599  2024          Zimbabwe                  Zimbabwe
#
#        Refugees under UNHCR's mandate  Asylum-seekers  \
# 0                                   0               0
# 1                                  28              36
# 2                                  12               0
# 3                                   5               0
# ...

# %%
df.to_csv('Refugees_CleanedData.csv')
